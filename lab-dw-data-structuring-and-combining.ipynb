# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import numpy as np
import pandas as pd

url_1 = ('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv')
url_2 = ('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')
url_3 = ('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv')

insurance_df = pd.read_csv(url_1)
policies_df = pd.read_csv(url_2)
docs_df = pd.read_csv(url_3)

# %%
insurance_df.columns = ['customer', 'state', 'gender', 'education', 'cus_life_val', 'income', 'monthly_prem_auto', 'num_open_complaints', 'policy_type', 'vehicle_class', 'total_claim_amount']


insurance_df.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'cus_life_val', 'income',
#        'monthly_prem_auto', 'num_open_complaints', 'policy_type',
#        'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
policies_df.columns = ['customer', 'state', 'gender', 'education', 'cus_life_val', 'income', 'monthly_prem_auto', 'num_open_complaints', 'total_claim_amount', 'policy_type', 'vehicle_class']


policies_df.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'cus_life_val', 'income',
#        'monthly_prem_auto', 'num_open_complaints', 'total_claim_amount',
#        'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
docs_df.columns = ['customer', 'state', 'cus_life_val', 'education', 'gender', 'income', 'monthly_prem_auto', 'num_open_complaints', 'policy_type', 'total_claim_amount', 'vehicle_class']


docs_df.columns
# Out:
# Index(['customer', 'state', 'cus_life_val', 'education', 'gender', 'income',
#        'monthly_prem_auto', 'num_open_complaints', 'policy_type',
#        'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
combo_df = pd.concat([insurance_df, policies_df, docs_df], axis=0)

combo_df
# Out:
#      customer       state gender             education cus_life_val   income  \
# 0     RB50392  Washington    NaN                Master          NaN      0.0
# 1     QZ44356     Arizona      F              Bachelor   697953.59%      0.0
# 2     AI49188      Nevada      F              Bachelor  1288743.17%  48767.0
# 3     WW63253  California      M              Bachelor   764586.18%      0.0
# 4     GA49547  Washington      M  High School or Below   536307.65%  36357.0
# ...       ...         ...    ...                   ...          ...      ...
# 7065  LA72316  California      M              Bachelor  23405.98798  71941.0
# 7066  PK87824  California      F               College  3096.511217  21604.0
# 7067  TD14365  California      M              Bachelor  8163.890428      0.0
# 7068  UP19263  California      M               College  7524.442436  21941.0
# 7069  Y167826  California      M               College  2611.836866      0.0
#
# ...

# %%
combo_df.gender = combo_df['gender'].apply(lambda x: 'F' if x in ['female', 'Femal', 'F'] else ('M' if x in ['Male', 'M'] else x))

combo_df.state = combo_df['state'].apply(lambda x: 'Arizona' if x in ['AZ'] else 'California' if x in ['Cali'] else 'Washington' if x in ['WA'] else x)

combo_df.vehicle_class = combo_df['vehicle_class'].apply(lambda x: 'Sedan' if x in ['Four-Door Car'] else 'Coupe' if x in ['Two-Door Car'] else 'Luxury' if x in ['Luxury SUV', 'Luxury Car'] else x) 

combo_df.education = combo_df['education'].apply(lambda x: 'Bachelors' if x in ['Bachelor'] else x)

combo_df['cus_life_val'] = combo_df['cus_life_val'].str.replace('%', '')

combo_df['num_open_complaints'] = combo_df['num_open_complaints'].apply(lambda x: x.split("/")[1] if isinstance(x, str) else x)

# %%
combo_df
# Out:
#      customer       state gender             education cus_life_val   income  \
# 0     RB50392  Washington    NaN                Master          NaN      0.0
# 1     QZ44356     Arizona      F             Bachelors    697953.59      0.0
# 2     AI49188      Nevada      F             Bachelors   1288743.17  48767.0
# 3     WW63253  California      M             Bachelors    764586.18      0.0
# 4     GA49547  Washington      M  High School or Below    536307.65  36357.0
# ...       ...         ...    ...                   ...          ...      ...
# 7065  LA72316  California      M             Bachelors          NaN  71941.0
# 7066  PK87824  California      F               College          NaN  21604.0
# 7067  TD14365  California      M             Bachelors          NaN      0.0
# 7068  UP19263  California      M               College          NaN  21941.0
# 7069  Y167826  California      M               College          NaN      0.0
#
# ...

# %%
combo_df['cus_life_val'] = combo_df['cus_life_val'].fillna(0)
combo_df['gender'] = combo_df['gender'].fillna('na')
combo_df['customer'] = combo_df['customer'].fillna('na')
combo_df['state'] = combo_df['state'].fillna('na')
combo_df['education'] = combo_df['education'].fillna('na')
combo_df['income'] = combo_df['income'].fillna(0)
combo_df['monthly_prem_auto'] = combo_df['monthly_prem_auto'].fillna(0)
combo_df['total_claim_amount'] = combo_df['total_claim_amount'].fillna(0)
combo_df['num_open_complaints'] = combo_df['num_open_complaints'].fillna('na')
combo_df['policy_type'] = combo_df['policy_type'].fillna('na')
combo_df['vehicle_class'] = combo_df['vehicle_class'].fillna('na')

# %%
combo_df['cus_life_val'] = combo_df['cus_life_val'].astype(float)

# %%
combo_df.isnull().sum()
# Out:
# customer               0
# state                  0
# gender                 0
# education              0
# cus_life_val           0
# income                 0
# monthly_prem_auto      0
# num_open_complaints    0
# policy_type            0
# vehicle_class          0
# total_claim_amount     0
# dtype: int64

# %%
combo_df.duplicated().sum()
# Out:
# 0

# %%
combo_df.drop_duplicates(inplace=True)

# %%
combo_df_wo_dups = insurance_df.copy()

combo_df_wo_dups.reset_index(drop=True, inplace=True)

# %%
combo_df
# Out:
#      customer       state gender             education  cus_life_val   income  \
# 0     RB50392  Washington     na                Master          0.00      0.0
# 1     QZ44356     Arizona      F             Bachelors     697953.59      0.0
# 2     AI49188      Nevada      F             Bachelors    1288743.17  48767.0
# 3     WW63253  California      M             Bachelors     764586.18      0.0
# 4     GA49547  Washington      M  High School or Below     536307.65  36357.0
# ...       ...         ...    ...                   ...           ...      ...
# 7065  LA72316  California      M             Bachelors          0.00  71941.0
# 7066  PK87824  California      F               College          0.00  21604.0
# 7067  TD14365  California      M             Bachelors          0.00      0.0
# 7068  UP19263  California      M               College          0.00  21941.0
# 7069  Y167826  California      M               College          0.00      0.0
#
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
import numpy as np
import pandas as pd

url = ('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv')

df = pd.read_csv(url)

# %%
df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
df.sales_channel.value_counts()
# Out:
# sales_channel
# Agent          4121
# Branch         3022
# Call Center    2141
# Web            1626
# Name: count, dtype: int64

# %%
df['total_revenue'] = round(df['number_of_policies']*df['monthly_premium_auto'], 2)

# %%
pivot_df = df.pivot_table(index='sales_channel', values=['total_revenue'], aggfunc='sum')

pivot_df

#agents sold the most
# Out:
#                total_revenue
# sales_channel
# Agent                1130616
# Branch                818951
# Call Center           589902
# Web                   471197

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_df_1 = df.pivot_table(index='education', columns='gender', values=['customer_lifetime_value'], aggfunc='mean').round(2)

pivot_df_1

#lowest is F with Doctor education, highest is F with high schoolm or below education
# Out:
#                      customer_lifetime_value
# gender                                     F        M
# education
# Bachelor                             7874.27  7703.60
# College                              7748.82  8052.46
# Doctor                               7328.51  7415.33
# High School or Below                 8675.22  8149.69
# Master                               8157.05  8168.83

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*
